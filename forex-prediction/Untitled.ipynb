# %%
import requests
import json
import pandas as pd

url = 'https://www.alphavantage.co/query?function=FX_DAILY&from_symbol=INR&to_symbol=USD&apikey=4B1MJYHIH3MK5EEC'
r = requests.get(url)
data = r.json()
#print(type(data))
#print(data)

df = pd.DataFrame.from_dict(data, orient ='index')
print(df)

#forex_data = json.loads(str(data))

#print('Forex Data\n'+str(forex_data))
# Out:
#                                                      1. Information  \
# Meta Data               Forex Daily Prices (open, high, low, close)
# Time Series FX (Daily)                                          NaN
#
#                        2. From Symbol 3. To Symbol 4. Output Size  \
# Meta Data                         INR          USD        Compact
# Time Series FX (Daily)            NaN          NaN            NaN
#
#                           5. Last Refreshed 6. Time Zone  \
# Meta Data               2022-10-07 21:55:00          UTC
# Time Series FX (Daily)                  NaN          NaN
#
#                                                                2022-10-07  \
# Meta Data                                                             NaN
# Time Series FX (Daily)  {'1. open': '0.01214', '2. high': '0.01217', '...
#
#                                                                2022-10-06  \
# Meta Data                                                             NaN
# ...
